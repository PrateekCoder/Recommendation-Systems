# %% [markdown]
# <a href="https://colab.research.google.com/github/PrateekCoder/Recommendation-Systems/blob/main/Content_Based_Movie_Recommendation_System_Using_LSA_Dimensionality_Reduction_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import all the required packages
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Import the imdb movies dataset
df = pd.read_csv('imdb_movie_data.csv')

# %%
df
# Out:
#         Unnamed: 0    index     tconst titleType  \
# 0                0    16917  tt0035423     movie
# 1                1    38887  tt0062336     movie
# 2                2    44457  tt0069049     movie
# 3                3    53246  tt0079644     movie
# 4                4    60711  tt0088751     movie
# ...            ...      ...        ...       ...
# 131249      131249  1004968  tt9916270     movie
# 131250      131250  1004971  tt9916362     movie
# 131251      131251  1004974  tt9916428     movie
# 131252      131252  1004979  tt9916538     movie
# 131253      131253  1004990  tt9916730     movie
#
#                                                     Title  Year  \
# 0                                          Kate & Leopold  2001
# 1       The Tango of the Widower and Its Distorting Mi...  2020
# 2                              The Other Side of the Wind  2018
# 3                                           November 1828  2001
# 4                                       The Naked Monster  2005
# ...                                                   ...   ...
# 131249                           Il talento del calabrone  2020
# 131250                                              Coven  2020
# 131251                                The Secret of China  2019
# 131252                                Kuambil Lagi Hatiku  2019
# 131253                                             6 Gunn  2017
#
#         runtimeMinutes                  genres                     directors  \
# 0                118.0  Comedy,Fantasy,Romance                 James Mangold
# 1                 70.0                   Drama  Raúl Ruiz, Valeria Sarmiento
# 2                122.0                   Drama                  Orson Welles
# 3                140.0               Drama,War                   Teguh Karya
# 4                100.0    Comedy,Horror,Sci-Fi     Wayne Berwick, Ted Newsom
# ...                ...                     ...                           ...
# 131249            84.0                Thriller                Giacomo Cimini
# 131250            92.0           Drama,History                  Pablo Agüero
# 131251             NaN   Adventure,History,War                   Jixing Wang
# 131252           123.0                   Drama             Azhar Kinoi Lubis
# 131253           116.0                     NaN                  Kiran Gawade
#
#                                               writers  averageRating  \
# 0                        Steven Rogers, James Mangold            6.4
# 1                     Raúl Ruiz, Omar Saavedra Santis            6.4
# 2                             Orson Welles, Oja Kodar            6.7
# 3                                         Teguh Karya            6.8
# 4                                          Ted Newsom            5.2
# ...                                               ...            ...
# 131249               Giacomo Cimini, Lorenzo Collalti            5.8
# 131250                   Pablo Agüero, Katell Guillou            6.4
# 131251                                             \N            3.8
# 131252  Arief Ash Siddiq, Rino Sarjono, Salman Aristo            8.3
# 131253                                   Kiran Gawade            8.3
#
#         numVotes                                             actors  \
# 0          86032  Hugh Jackman, Meg Ryan, Breckin Meyer, Liev Sc...
# 1            164  Claudia Paz, Rubén Sotoconil, Shenda Román, Lu...
# 2           7565  John Huston, Peter Bogdanovich, Susan Strasber...
# 3            214  Rachmat Hidayat, El Manik, Soerip, Jenny Rachm...
# 4            329  John Goodwin, R.G. Wilson, Kenneth Tobey, Brin...
# ...          ...                                                ...
# 131249      1394  Sergio Castellitto, Lorenzo Richelmy, Anna Fog...
# 131250      5182  Amaia Aberasturi, Daniel Fanego, Garazi Urkola...
# 131251        14  Wang Peng Kai, Valery Gadreau, Wenli Jiang, Vi...
# 131252         6  Lala Karmela, Cut Mini Theo, Ria Irawan, Sahil...
# 131253        10  Bhushan Pradhan, Ganesh Vasant Patil, Sunil Ba...
#
#                                                     Movie
# 0                                   Kate & Leopold (2001)
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                       The Other Side of the Wind (2018)
# 3                                    November 1828 (2001)
# 4                                The Naked Monster (2005)
# ...                                                   ...
# 131249                    Il talento del calabrone (2020)
# 131250                                       Coven (2020)
# 131251                         The Secret of China (2019)
# 131252                         Kuambil Lagi Hatiku (2019)
# 131253                                      6 Gunn (2017)
#
# [131254 rows x 14 columns]

# %%
# Combine movie name and tags into a single string
df['content'] = df['Movie'].astype(str) + ' ' + df['runtimeMinutes'].astype(str) + ' ' + df['genres'] + ' ' + df['directors'] + ' ' + df['writers'] + ' ' + df['averageRating'].astype(str) + ' ' + df['numVotes'].astype(str) + df['actors'].astype(str)
df['content'] = df['content'].fillna('')

# %%
# Create bag of words
vectorizer = CountVectorizer()
bow = vectorizer.fit_transform(df['content'])

# %%
# Convert bag of words to TF-IDF
tfidf_transformer = TfidfTransformer()
tfidf = tfidf_transformer.fit_transform(bow)

# %%
# Apply LSA or LSI
lsa = TruncatedSVD(n_components=100, algorithm='arpack')
lsa.fit(tfidf)
# Out:
# TruncatedSVD(algorithm='arpack', n_components=100)

# %%
# Get the user input
user_movie = input("Enter a movie title: ")
# Out:
# Enter a movie title: The Prestige (2006)

# %%
# Find the index of the user movie
movie_index = df[df['Movie'] == user_movie].index[0]

# Compute the cosine similarities between the user movie and all other movies
similarity_scores = cosine_similarity(tfidf[movie_index], tfidf)

# Get the top 10 most similar movies
similar_movies = list(enumerate(similarity_scores[0]))
sorted_similar_movies = sorted(similar_movies, key=lambda x: x[1], reverse=True)[1:20]

# Print the top 10 similar movies
for i, score in sorted_similar_movies:
    print("{}: {}".format(i, df.loc[i, 'Movie']))
# Out:
# 17830: The Dark Knight (2008)
# 44912: The Dark Knight Rises (2012)
# 21896: Interstellar (2014)
# 993: Memento (2000)
# 10527: Batman Begins (2005)
# 115499: Tenet (2020)
# 46363: Inception (2010)
# 103035: Dunkirk (2017)
# 59251: I Kissed a Vampire (2010)
# 76235: No Way Out But One (2011)
# 47516: Broken Contact: A Poltergeist Story (2020)
# 40126: Memories of Reality (2021)
# 97983: Pause of the Clock (2015)
# 1782: Dr. Benny (2003)
# 20624: Man of Steel (2013)
# 4081: Insomnia (2002)
# 102831: Turn in Your Grave (2012)
# 32090: Montana (2008)
# 9361: Meridian (2002)
